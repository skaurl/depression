# %%
from google.colab import drive
drive.mount('/gdrive')

# %%
# !pip install konlpy
# !pip install kss

# %%
# !git clone https://github.com/SOMJANG/Mecab-ko-for-Google-Colab.git

# %%
cd Mecab-ko-for-Google-Colab

# %%
# !bash install_mecab-ko_on_colab190912.sh

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import copy
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN, Activation
from tensorflow.keras import optimizers
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder; LE = LabelEncoder()
from sklearn.metrics import classification_report
from gensim.models.word2vec import Word2Vec
from konlpy.tag import Mecab

def rnn():
    model = Sequential()
    model.add(SimpleRNN(2 ** 3, input_shape=(max_len*100, 1), return_sequences=True))
    model.add(SimpleRNN(2 ** 3, return_sequences=True))
    model.add(SimpleRNN(2 ** 3, return_sequences=False))

    model.add(Dense(2))
    model.add(Activation('softmax'))
    adam = optimizers.Adam(lr=0.001)
    model.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy'])
    model.summary()
    early_stopping = EarlyStopping(patience=10)
    history = model.fit(x_train, y_train, validation_split=0.1, epochs=epochs, batch_size=batch_size, verbose=1, callbacks=[early_stopping])

    return model, history

if __name__ == "__main__":
    max_len = 32
    epochs = 2 ** 10
    batch_size = 2 ** 10

    mecab = Mecab()

    model = Word2Vec.load('/gdrive/My Drive/한양대학교/2020 프로젝트 학기제/TEST/word2vec')

    depression_dataset_path = r'/gdrive/My Drive/한양대학교/2020 프로젝트 학기제/TEST/depression_dataset_맞춤법O.csv'

    depression_dataset = pd.read_csv(depression_dataset_path, encoding='cp949')

    df = []

    for i in range(len(depression_dataset)):
        df.append(mecab.morphs(depression_dataset.iloc[i,0]))

    for i in range(len(df)):
        for j in range(len(df[i])):
            try:
                df[i][j] = model.wv.get_vector(df[i][j]).tolist()
            except:
                df[i][j] = False

    for i in range(len(df)):
        while False in df[i]:
            df[i].remove(False)

    for i in range(len(df)):
        if len(df[i]) >= max_len:
            df[i] = df[i][-32:]
        else:
            for j in range(max_len-len(df[i])):
                df[i].insert(0,0)

    for i in range(len(df)):
        for j in range(len(df[i])):
            if df[i][j] == 0:
                df[i][j] = [0]*100

    depression_dataset['label_1'] = LE.fit_transform(depression_dataset['label_1'])

    x_train, x_test, y_train, y_test = train_test_split(df, depression_dataset['label_1'], test_size=0.1, random_state=42)

    x_train = np.array(x_train).reshape((len(x_train), max_len*100, 1))
    x_test = np.array(x_test).reshape((len(x_test), max_len*100, 1))

    y_true = copy.deepcopy(y_test)
    y_train = to_categorical(y_train)
    y_test = to_categorical(y_test)

    print('train_shape : {} / {}'.format(x_train.shape, y_train.shape))
    print('test_shape : {} / {}'.format(x_test.shape, y_test.shape))

    model, history = rnn()

    scores = model.evaluate(x_test, y_test)
    print(scores)
    print("정확도: %.2f%%" % (scores[1] * 100))

    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs = range(1, len(acc) + 1)

    plt.plot(epochs, loss, 'r', label='Training loss')
    plt.plot(epochs, val_loss, 'b', label='Validation loss')
    plt.title('Training and validation loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.figure()
    plt.plot(epochs, acc, 'r', label='Training acc')
    plt.plot(epochs, val_acc, 'b', label='Validation acc')
    plt.title('Training and validation accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.show()

    y_true = list(y_true)
    y_pred = model.predict_classes(x_test)
    y_pred = list(y_pred)

    print(classification_report(y_true, y_pred))
    print(pd.crosstab(pd.Series(y_true), pd.Series(y_pred), rownames=['True'], colnames=['Predicted']))
# Out:
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:254: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# train_shape : (25873, 3200, 1) / (25873, 2)
# test_shape : (2875, 3200, 1) / (2875, 2)
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_2 (SimpleRNN)     (None, 3200, 8)           80
# _________________________________________________________________
# simple_rnn_3 (SimpleRNN)     (None, 3200, 8)           136
# _________________________________________________________________
# simple_rnn_4 (SimpleRNN)     (None, 8)                 136
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 18
# _________________________________________________________________
# activation_1 (Activation)    (None, 2)                 0
# =================================================================
# Total params: 370
# Trainable params: 370
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1024
# 23/23 [==============================] - 102s 4s/step - loss: 0.6805 - accuracy: 0.5626 - val_loss: 0.6605 - val_accuracy: 0.5711
# Epoch 2/1024
# 23/23 [==============================] - 102s 4s/step - loss: 0.6598 - accuracy: 0.5939 - val_loss: 0.6470 - val_accuracy: 0.6252
# Epoch 3/1024
# 23/23 [==============================] - 102s 4s/step - loss: 0.6471 - accuracy: 0.6226 - val_loss: 0.6326 - val_accuracy: 0.6345
# Epoch 4/1024
# 23/23 [==============================] - 101s 4s/step - loss: 0.6399 - accuracy: 0.6264 - val_loss: 0.6269 - val_accuracy: 0.6360
# Epoch 5/1024
# 23/23 [==============================] - 101s 4s/step - loss: 0.6351 - accuracy: 0.6334 - val_loss: 0.6203 - val_accuracy: 0.6464
# Epoch 6/1024
# 23/23 [==============================] - 102s 4s/step - loss: 0.6308 - accuracy: 0.6429 - val_loss: 0.6154 - val_accuracy: 0.6546
# Epoch 7/1024
# 23/23 [==============================] - 102s 4s/step - loss: 0.6284 - accuracy: 0.6469 - val_loss: 0.6115 - val_accuracy: 0.6549
# Epoch 8/1024
# 23/23 [==============================] - 102s 4s/step - loss: 0.6261 - accuracy: 0.6472 - val_loss: 0.6097 - val_accuracy: 0.6611
# Epoch 9/1024
# 23/23 [==============================] - 102s 4s/step - loss: 0.6233 - accuracy: 0.6460 - val_loss: 0.6056 - val_accuracy: 0.6619
# Epoch 10/1024
# 23/23 [==============================] - 102s 4s/step - loss: 0.6197 - accuracy: 0.6478 - val_loss: 0.6020 - val_accuracy: 0.6627
# Epoch 11/1024
# 23/23 [==============================] - 102s 4s/step - loss: 0.6171 - accuracy: 0.6511 - val_loss: 0.5993 - val_accuracy: 0.6766
# Epoch 12/1024
# 23/23 [==============================] - 102s 4s/step - loss: 0.6137 - accuracy: 0.6578 - val_loss: 0.5956 - val_accuracy: 0.6843
# Epoch 13/1024
# 23/23 [==============================] - 103s 4s/step - loss: 0.6123 - accuracy: 0.6594 - val_loss: 0.5954 - val_accuracy: 0.6797
# Epoch 14/1024
# 23/23 [==============================] - 101s 4s/step - loss: 0.6110 - accuracy: 0.6601 - val_loss: 0.5969 - val_accuracy: 0.6789
# Epoch 15/1024
# 23/23 [==============================] - 101s 4s/step - loss: 0.6105 - accuracy: 0.6627 - val_loss: 0.5927 - val_accuracy: 0.6882
# Epoch 16/1024
# 23/23 [==============================] - 102s 4s/step - loss: 0.6081 - accuracy: 0.6639 - val_loss: 0.5916 - val_accuracy: 0.6924
# Epoch 17/1024
# 23/23 [==============================] - 102s 4s/step - loss: 0.6070 - accuracy: 0.6648 - val_loss: 0.5906 - val_accuracy: 0.6847
# Epoch 18/1024
# 23/23 [==============================] - 102s 4s/step - loss: 0.6072 - accuracy: 0.6673 - val_loss: 0.5902 - val_accuracy: 0.6847
# Epoch 19/1024
# 23/23 [==============================] - 102s 4s/step - loss: 0.6056 - accuracy: 0.6666 - val_loss: 0.5891 - val_accuracy: 0.6917
# Epoch 20/1024
# 23/23 [==============================] - 102s 4s/step - loss: 0.6048 - accuracy: 0.6698 - val_loss: 0.5916 - val_accuracy: 0.6882
# Epoch 21/1024
# 23/23 [==============================] - 102s 4s/step - loss: 0.6042 - accuracy: 0.6699 - val_loss: 0.5936 - val_accuracy: 0.6862
# Epoch 22/1024
# 23/23 [==============================] - 102s 4s/step - loss: 0.6038 - accuracy: 0.6714 - val_loss: 0.5883 - val_accuracy: 0.6920
# Epoch 23/1024
# 23/23 [==============================] - 102s 4s/step - loss: 0.6022 - accuracy: 0.6729 - val_loss: 0.5885 - val_accuracy: 0.6886
# Epoch 24/1024
# 23/23 [==============================] - 102s 4s/step - loss: 0.6021 - accuracy: 0.6729 - val_loss: 0.5866 - val_accuracy: 0.6917
# Epoch 25/1024
# 23/23 [==============================] - 102s 4s/step - loss: 0.6010 - accuracy: 0.6731 - val_loss: 0.5879 - val_accuracy: 0.6859
# Epoch 26/1024
# 23/23 [==============================] - 102s 4s/step - loss: 0.6008 - accuracy: 0.6732 - val_loss: 0.5893 - val_accuracy: 0.6816
# Epoch 27/1024
# 23/23 [==============================] - 102s 4s/step - loss: 0.6086 - accuracy: 0.6663 - val_loss: 0.6146 - val_accuracy: 0.6615
# Epoch 28/1024
# 23/23 [==============================] - 102s 4s/step - loss: 0.6205 - accuracy: 0.6566 - val_loss: 0.5976 - val_accuracy: 0.6862
# Epoch 29/1024
# 23/23 [==============================] - 103s 4s/step - loss: 0.6083 - accuracy: 0.6701 - val_loss: 0.5890 - val_accuracy: 0.6917
# Epoch 30/1024
# 23/23 [==============================] - 102s 4s/step - loss: 0.6024 - accuracy: 0.6748 - val_loss: 0.5850 - val_accuracy: 0.6924
# Epoch 31/1024
# 23/23 [==============================] - 102s 4s/step - loss: 0.5992 - accuracy: 0.6750 - val_loss: 0.5848 - val_accuracy: 0.6905
# Epoch 32/1024
# 23/23 [==============================] - 103s 4s/step - loss: 0.5990 - accuracy: 0.6743 - val_loss: 0.5881 - val_accuracy: 0.6882
# Epoch 33/1024
# 23/23 [==============================] - 103s 4s/step - loss: 0.6006 - accuracy: 0.6735 - val_loss: 0.5828 - val_accuracy: 0.6913
# Epoch 34/1024
# 23/23 [==============================] - 102s 4s/step - loss: 0.5990 - accuracy: 0.6754 - val_loss: 0.5832 - val_accuracy: 0.6866
# Epoch 35/1024
# 23/23 [==============================] - 102s 4s/step - loss: 0.5978 - accuracy: 0.6776 - val_loss: 0.5810 - val_accuracy: 0.6940
# Epoch 36/1024
# 23/23 [==============================] - 102s 4s/step - loss: 0.5963 - accuracy: 0.6782 - val_loss: 0.5804 - val_accuracy: 0.6882
# Epoch 37/1024
# 23/23 [==============================] - 102s 4s/step - loss: 0.5954 - accuracy: 0.6790 - val_loss: 0.5801 - val_accuracy: 0.6897
# Epoch 38/1024
# 23/23 [==============================] - 102s 4s/step - loss: 0.5956 - accuracy: 0.6784 - val_loss: 0.5793 - val_accuracy: 0.6963
# Epoch 39/1024
# 23/23 [==============================] - 102s 4s/step - loss: 0.5951 - accuracy: 0.6776 - val_loss: 0.5778 - val_accuracy: 0.6936
# Epoch 40/1024
# 23/23 [==============================] - 102s 4s/step - loss: 0.5938 - accuracy: 0.6800 - val_loss: 0.5767 - val_accuracy: 0.6974
# Epoch 41/1024
# 23/23 [==============================] - 101s 4s/step - loss: 0.5940 - accuracy: 0.6804 - val_loss: 0.5797 - val_accuracy: 0.6959
# Epoch 42/1024
# 23/23 [==============================] - 103s 4s/step - loss: 0.5933 - accuracy: 0.6791 - val_loss: 0.5757 - val_accuracy: 0.6936
# Epoch 43/1024
# 23/23 [==============================] - 103s 4s/step - loss: 0.5936 - accuracy: 0.6810 - val_loss: 0.5809 - val_accuracy: 0.6874
# Epoch 44/1024
# 23/23 [==============================] - 103s 4s/step - loss: 0.5942 - accuracy: 0.6798 - val_loss: 0.5799 - val_accuracy: 0.6951
# Epoch 45/1024
# 23/23 [==============================] - 103s 4s/step - loss: 0.5932 - accuracy: 0.6808 - val_loss: 0.5792 - val_accuracy: 0.6982
# Epoch 46/1024
# 23/23 [==============================] - 106s 5s/step - loss: 0.5923 - accuracy: 0.6813 - val_loss: 0.5775 - val_accuracy: 0.6812
# Epoch 47/1024
# 23/23 [==============================] - 105s 5s/step - loss: 0.5930 - accuracy: 0.6788 - val_loss: 0.5791 - val_accuracy: 0.6940
# Epoch 48/1024
# 23/23 [==============================] - 102s 4s/step - loss: 0.5919 - accuracy: 0.6826 - val_loss: 0.5762 - val_accuracy: 0.7013
# Epoch 49/1024
# 23/23 [==============================] - 102s 4s/step - loss: 0.5928 - accuracy: 0.6827 - val_loss: 0.5754 - val_accuracy: 0.6978
# Epoch 50/1024
# 23/23 [==============================] - 103s 4s/step - loss: 0.5916 - accuracy: 0.6832 - val_loss: 0.5738 - val_accuracy: 0.6978
# Epoch 51/1024
# 23/23 [==============================] - 102s 4s/step - loss: 0.5922 - accuracy: 0.6822 - val_loss: 0.5764 - val_accuracy: 0.6920
# Epoch 52/1024
# 23/23 [==============================] - 102s 4s/step - loss: 0.5912 - accuracy: 0.6823 - val_loss: 0.5741 - val_accuracy: 0.6978
# Epoch 53/1024
# 23/23 [==============================] - 102s 4s/step - loss: 0.5900 - accuracy: 0.6838 - val_loss: 0.5760 - val_accuracy: 0.6909
# Epoch 54/1024
# 23/23 [==============================] - 102s 4s/step - loss: 0.5913 - accuracy: 0.6836 - val_loss: 0.5732 - val_accuracy: 0.7036
# Epoch 55/1024
# 23/23 [==============================] - 101s 4s/step - loss: 0.5901 - accuracy: 0.6841 - val_loss: 0.5742 - val_accuracy: 0.6920
# Epoch 56/1024
# 23/23 [==============================] - 102s 4s/step - loss: 0.5900 - accuracy: 0.6833 - val_loss: 0.5742 - val_accuracy: 0.6944
# Epoch 57/1024
# 23/23 [==============================] - 103s 4s/step - loss: 0.5892 - accuracy: 0.6831 - val_loss: 0.5773 - val_accuracy: 0.6936
# Epoch 58/1024
# 23/23 [==============================] - 102s 4s/step - loss: 0.5888 - accuracy: 0.6840 - val_loss: 0.5747 - val_accuracy: 0.6974
# Epoch 59/1024
# 23/23 [==============================] - 102s 4s/step - loss: 0.5906 - accuracy: 0.6839 - val_loss: 0.5750 - val_accuracy: 0.6963
# Epoch 60/1024
# 23/23 [==============================] - 103s 4s/step - loss: 0.5923 - accuracy: 0.6794 - val_loss: 0.5784 - val_accuracy: 0.6924
# Epoch 61/1024
# 23/23 [==============================] - 103s 4s/step - loss: 0.5900 - accuracy: 0.6849 - val_loss: 0.5735 - val_accuracy: 0.6955
# Epoch 62/1024
# 23/23 [==============================] - 103s 4s/step - loss: 0.5893 - accuracy: 0.6856 - val_loss: 0.5746 - val_accuracy: 0.6990
# Epoch 63/1024
# 23/23 [==============================] - 103s 4s/step - loss: 0.5888 - accuracy: 0.6848 - val_loss: 0.5733 - val_accuracy: 0.6974
# Epoch 64/1024
# 23/23 [==============================] - 103s 4s/step - loss: 0.5886 - accuracy: 0.6846 - val_loss: 0.5713 - val_accuracy: 0.7002
# Epoch 65/1024
# 23/23 [==============================] - 103s 4s/step - loss: 0.5895 - accuracy: 0.6861 - val_loss: 0.5761 - val_accuracy: 0.6940
# Epoch 66/1024
# 23/23 [==============================] - 103s 4s/step - loss: 0.5874 - accuracy: 0.6854 - val_loss: 0.5688 - val_accuracy: 0.7005
# Epoch 67/1024
# 23/23 [==============================] - 103s 4s/step - loss: 0.5876 - accuracy: 0.6879 - val_loss: 0.5709 - val_accuracy: 0.6951
# Epoch 68/1024
# 23/23 [==============================] - 103s 4s/step - loss: 0.5887 - accuracy: 0.6835 - val_loss: 0.5702 - val_accuracy: 0.6998
# Epoch 69/1024
# 23/23 [==============================] - 103s 4s/step - loss: 0.5906 - accuracy: 0.6834 - val_loss: 0.5788 - val_accuracy: 0.6951
# Epoch 70/1024
# 23/23 [==============================] - 103s 4s/step - loss: 0.5914 - accuracy: 0.6834 - val_loss: 0.5723 - val_accuracy: 0.7040
# Epoch 71/1024
# 23/23 [==============================] - 103s 4s/step - loss: 0.5889 - accuracy: 0.6841 - val_loss: 0.5697 - val_accuracy: 0.7017
# Epoch 72/1024
# 23/23 [==============================] - 103s 4s/step - loss: 0.5872 - accuracy: 0.6874 - val_loss: 0.5737 - val_accuracy: 0.6955
# Epoch 73/1024
# 23/23 [==============================] - 107s 5s/step - loss: 0.5869 - accuracy: 0.6880 - val_loss: 0.5753 - val_accuracy: 0.6928
# Epoch 74/1024
# 23/23 [==============================] - 107s 5s/step - loss: 0.5874 - accuracy: 0.6878 - val_loss: 0.5703 - val_accuracy: 0.6994
# Epoch 75/1024
# 23/23 [==============================] - 104s 5s/step - loss: 0.5857 - accuracy: 0.6866 - val_loss: 0.5732 - val_accuracy: 0.6990
# Epoch 76/1024
# 23/23 [==============================] - 103s 4s/step - loss: 0.5868 - accuracy: 0.6893 - val_loss: 0.5707 - val_accuracy: 0.6990
# 90/90 [==============================] - 20s 219ms/step - loss: 0.5723 - accuracy: 0.7002
# [0.5723390579223633, 0.7001739144325256]
# 정확도: 70.02%
#               precision    recall  f1-score   support
#
#            0       0.75      0.60      0.67      1428
#            1       0.67      0.80      0.73      1447
#
#     accuracy                           0.70      2875
#    macro avg       0.71      0.70      0.70      2875
# weighted avg       0.71      0.70      0.70      2875
#
# Predicted    0     1
# True
# 0          857   571
# 1          291  1156
