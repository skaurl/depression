# %%
from google.colab import drive
drive.mount('/gdrive')

# %%
# !pip install konlpy
# !pip install kss

# %%
# !git clone https://github.com/SOMJANG/Mecab-ko-for-Google-Colab.git

# %%
cd Mecab-ko-for-Google-Colab

# %%
# !bash install_mecab-ko_on_colab190912.sh

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import copy
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN, Activation
from tensorflow.keras import optimizers
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder; LE = LabelEncoder()
from sklearn.metrics import classification_report
from gensim.models.word2vec import Word2Vec
from konlpy.tag import Mecab

def rnn():
    model = Sequential()
    model.add(SimpleRNN(2 ** 5, input_shape=(max_len*100, 1), return_sequences=True))
    model.add(SimpleRNN(2 ** 5, return_sequences=True))
    model.add(SimpleRNN(2 ** 5, return_sequences=False))

    model.add(Dense(10))
    model.add(Activation('softmax'))
    adam = optimizers.Adam(lr=0.001)
    model.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy'])
    model.summary()
    early_stopping = EarlyStopping(patience=10)
    history = model.fit(x_train, y_train, validation_split=0.1, epochs=epochs, batch_size=batch_size, verbose=1, callbacks=[early_stopping])

    return model, history

if __name__ == "__main__":
    max_len = 32
    epochs = 2 ** 10
    batch_size = 2 ** 10

    mecab = Mecab()

    model = Word2Vec.load('/gdrive/My Drive/한양대학교/2020 프로젝트 학기제/TEST/word2vec')

    depression_dataset_path = r'/gdrive/My Drive/한양대학교/2020 프로젝트 학기제/TEST/depression_dataset_맞춤법O.csv'

    depression_dataset = pd.read_csv(depression_dataset_path, encoding='cp949')
    depression_dataset = depression_dataset[depression_dataset['label_1']=='Y']
    
    df = []

    for i in range(len(depression_dataset)):
        df.append(mecab.morphs(depression_dataset.iloc[i,0]))

    for i in range(len(df)):
        for j in range(len(df[i])):
            try:
                df[i][j] = model.wv.get_vector(df[i][j]).tolist()
            except:
                df[i][j] = False

    for i in range(len(df)):
        while False in df[i]:
            df[i].remove(False)

    for i in range(len(df)):
        if len(df[i]) >= max_len:
            df[i] = df[i][-32:]
        else:
            for j in range(max_len-len(df[i])):
                df[i].insert(0,0)

    for i in range(len(df)):
        for j in range(len(df[i])):
            if df[i][j] == 0:
                df[i][j] = [0]*100

    depression_dataset['label_2'] = LE.fit_transform(depression_dataset['label_2'])

    x_train, x_test, y_train, y_test = train_test_split(df, depression_dataset['label_2'], test_size=0.1, random_state=42)

    x_train = np.array(x_train).reshape((len(x_train), max_len*100, 1))
    x_test = np.array(x_test).reshape((len(x_test), max_len*100, 1))

    y_true = copy.deepcopy(y_test)
    y_train = to_categorical(y_train)
    y_test = to_categorical(y_test)

    print('train_shape : {} / {}'.format(x_train.shape, y_train.shape))
    print('test_shape : {} / {}'.format(x_test.shape, y_test.shape))

    model, history = rnn()

    scores = model.evaluate(x_test, y_test)
    print(scores)
    print("정확도: %.2f%%" % (scores[1] * 100))

    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs = range(1, len(acc) + 1)

    plt.plot(epochs, loss, 'r', label='Training loss')
    plt.plot(epochs, val_loss, 'b', label='Validation loss')
    plt.title('Training and validation loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.figure()
    plt.plot(epochs, acc, 'r', label='Training acc')
    plt.plot(epochs, val_acc, 'b', label='Validation acc')
    plt.title('Training and validation accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.show()

    y_true = list(y_true)
    y_pred = model.predict_classes(x_test)
    y_pred = list(y_pred)

    print(classification_report(y_true, y_pred))
    print(pd.crosstab(pd.Series(y_true), pd.Series(y_pred), rownames=['True'], colnames=['Predicted']))
# Out:
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:254: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# train_shape : (12984, 3200, 1) / (12984, 10)
# test_shape : (1443, 3200, 1) / (1443, 10)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn (SimpleRNN)       (None, 3200, 32)          1088
# _________________________________________________________________
# simple_rnn_1 (SimpleRNN)     (None, 3200, 32)          2080
# _________________________________________________________________
# simple_rnn_2 (SimpleRNN)     (None, 32)                2080
# _________________________________________________________________
# dense (Dense)                (None, 10)                330
# _________________________________________________________________
# activation (Activation)      (None, 10)                0
# =================================================================
# Total params: 5,578
# Trainable params: 5,578
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1024
# 12/12 [==============================] - 106s 9s/step - loss: 0.3278 - accuracy: 0.1174 - val_loss: 0.3160 - val_accuracy: 0.1416
# Epoch 2/1024
# 12/12 [==============================] - 103s 9s/step - loss: 0.3147 - accuracy: 0.1500 - val_loss: 0.3133 - val_accuracy: 0.1632
# Epoch 3/1024
# 12/12 [==============================] - 107s 9s/step - loss: 0.3124 - accuracy: 0.1582 - val_loss: 0.3113 - val_accuracy: 0.1794
# Epoch 4/1024
# 12/12 [==============================] - 107s 9s/step - loss: 0.3112 - accuracy: 0.1684 - val_loss: 0.3107 - val_accuracy: 0.1794
# Epoch 5/1024
# 12/12 [==============================] - 107s 9s/step - loss: 0.3105 - accuracy: 0.1724 - val_loss: 0.3100 - val_accuracy: 0.1963
# Epoch 6/1024
# 12/12 [==============================] - 106s 9s/step - loss: 0.3101 - accuracy: 0.1717 - val_loss: 0.3099 - val_accuracy: 0.2002
# Epoch 7/1024
# 12/12 [==============================] - 106s 9s/step - loss: 0.3098 - accuracy: 0.1751 - val_loss: 0.3102 - val_accuracy: 0.1809
# Epoch 8/1024
# 12/12 [==============================] - 108s 9s/step - loss: 0.3096 - accuracy: 0.1774 - val_loss: 0.3095 - val_accuracy: 0.1978
# Epoch 9/1024
# 12/12 [==============================] - 106s 9s/step - loss: 0.3093 - accuracy: 0.1815 - val_loss: 0.3095 - val_accuracy: 0.1978
# Epoch 10/1024
# 12/12 [==============================] - 106s 9s/step - loss: 0.3091 - accuracy: 0.1786 - val_loss: 0.3097 - val_accuracy: 0.1932
# Epoch 11/1024
# 12/12 [==============================] - 106s 9s/step - loss: 0.3090 - accuracy: 0.1777 - val_loss: 0.3097 - val_accuracy: 0.1901
# Epoch 12/1024
# 12/12 [==============================] - 106s 9s/step - loss: 0.3087 - accuracy: 0.1811 - val_loss: 0.3091 - val_accuracy: 0.1832
# Epoch 13/1024
# 12/12 [==============================] - 106s 9s/step - loss: 0.3084 - accuracy: 0.1825 - val_loss: 0.3097 - val_accuracy: 0.1925
# Epoch 14/1024
# 12/12 [==============================] - 106s 9s/step - loss: 0.3084 - accuracy: 0.1853 - val_loss: 0.3088 - val_accuracy: 0.1917
# Epoch 15/1024
# 12/12 [==============================] - 106s 9s/step - loss: 0.3083 - accuracy: 0.1890 - val_loss: 0.3092 - val_accuracy: 0.1832
# Epoch 16/1024
# 12/12 [==============================] - 106s 9s/step - loss: 0.3081 - accuracy: 0.1847 - val_loss: 0.3092 - val_accuracy: 0.1894
# Epoch 17/1024
# 12/12 [==============================] - 106s 9s/step - loss: 0.3079 - accuracy: 0.1931 - val_loss: 0.3092 - val_accuracy: 0.1940
# Epoch 18/1024
# 12/12 [==============================] - 106s 9s/step - loss: 0.3078 - accuracy: 0.1922 - val_loss: 0.3090 - val_accuracy: 0.1871
# Epoch 19/1024
# 12/12 [==============================] - 106s 9s/step - loss: 0.3079 - accuracy: 0.1876 - val_loss: 0.3092 - val_accuracy: 0.1894
# Epoch 20/1024
# 12/12 [==============================] - 106s 9s/step - loss: 0.3079 - accuracy: 0.1914 - val_loss: 0.3089 - val_accuracy: 0.1871
# Epoch 21/1024
# 12/12 [==============================] - 106s 9s/step - loss: 0.3076 - accuracy: 0.1948 - val_loss: 0.3090 - val_accuracy: 0.2055
# Epoch 22/1024
# 12/12 [==============================] - 106s 9s/step - loss: 0.3073 - accuracy: 0.1900 - val_loss: 0.3086 - val_accuracy: 0.1955
# Epoch 23/1024
# 12/12 [==============================] - 106s 9s/step - loss: 0.3072 - accuracy: 0.1952 - val_loss: 0.3091 - val_accuracy: 0.1909
# Epoch 24/1024
# 12/12 [==============================] - 107s 9s/step - loss: 0.3072 - accuracy: 0.1962 - val_loss: 0.3088 - val_accuracy: 0.2002
# Epoch 25/1024
# 12/12 [==============================] - 106s 9s/step - loss: 0.3069 - accuracy: 0.1994 - val_loss: 0.3090 - val_accuracy: 0.1917
# Epoch 26/1024
# 12/12 [==============================] - 107s 9s/step - loss: 0.3068 - accuracy: 0.1973 - val_loss: 0.3087 - val_accuracy: 0.1917
# Epoch 27/1024
# 12/12 [==============================] - 107s 9s/step - loss: 0.3067 - accuracy: 0.1963 - val_loss: 0.3087 - val_accuracy: 0.1909
# Epoch 28/1024
# 12/12 [==============================] - 106s 9s/step - loss: 0.3066 - accuracy: 0.1986 - val_loss: 0.3089 - val_accuracy: 0.2002
# Epoch 29/1024
# 12/12 [==============================] - 106s 9s/step - loss: 0.3065 - accuracy: 0.1988 - val_loss: 0.3095 - val_accuracy: 0.1863
# Epoch 30/1024
# 12/12 [==============================] - 106s 9s/step - loss: 0.3063 - accuracy: 0.1990 - val_loss: 0.3083 - val_accuracy: 0.1886
# Epoch 31/1024
# 12/12 [==============================] - 107s 9s/step - loss: 0.3061 - accuracy: 0.2018 - val_loss: 0.3090 - val_accuracy: 0.1932
# Epoch 32/1024
# 12/12 [==============================] - 106s 9s/step - loss: 0.3064 - accuracy: 0.1985 - val_loss: 0.3083 - val_accuracy: 0.1932
# Epoch 33/1024
# 12/12 [==============================] - 106s 9s/step - loss: 0.3062 - accuracy: 0.1992 - val_loss: 0.3091 - val_accuracy: 0.1878
# Epoch 34/1024
# 12/12 [==============================] - 106s 9s/step - loss: 0.3061 - accuracy: 0.2027 - val_loss: 0.3085 - val_accuracy: 0.1932
# Epoch 35/1024
# 12/12 [==============================] - 107s 9s/step - loss: 0.3060 - accuracy: 0.2003 - val_loss: 0.3090 - val_accuracy: 0.1848
# Epoch 36/1024
# 12/12 [==============================] - 107s 9s/step - loss: 0.3058 - accuracy: 0.2015 - val_loss: 0.3086 - val_accuracy: 0.1901
# Epoch 37/1024
# 12/12 [==============================] - 106s 9s/step - loss: 0.3058 - accuracy: 0.2033 - val_loss: 0.3100 - val_accuracy: 0.1724
# Epoch 38/1024
# 12/12 [==============================] - 106s 9s/step - loss: 0.3058 - accuracy: 0.2003 - val_loss: 0.3091 - val_accuracy: 0.1909
# Epoch 39/1024
# 12/12 [==============================] - 106s 9s/step - loss: 0.3053 - accuracy: 0.2055 - val_loss: 0.3088 - val_accuracy: 0.1871
# Epoch 40/1024
# 12/12 [==============================] - 106s 9s/step - loss: 0.3054 - accuracy: 0.2072 - val_loss: 0.3089 - val_accuracy: 0.2009
# Epoch 41/1024
# 12/12 [==============================] - 106s 9s/step - loss: 0.3051 - accuracy: 0.2062 - val_loss: 0.3087 - val_accuracy: 0.1794
# Epoch 42/1024
# 12/12 [==============================] - 106s 9s/step - loss: 0.3049 - accuracy: 0.2044 - val_loss: 0.3086 - val_accuracy: 0.1809
# 46/46 [==============================] - 18s 386ms/step - loss: 0.3063 - accuracy: 0.2024
# [0.30625900626182556, 0.20235620439052582]
# 정확도: 20.24%
# WARNING:tensorflow:From <ipython-input-6-29c4d3532b0d>:117: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#               precision    recall  f1-score   support
#
#            0       0.17      0.19      0.18       210
#            1       0.47      0.03      0.06       225
#            2       0.00      0.00      0.00        44
#            3       0.25      0.25      0.25       128
#            4       0.00      0.00      0.00        76
#            5       0.00      0.00      0.00        82
#            6       0.18      0.56      0.27       204
#            7       0.24      0.26      0.25       190
#            8       0.00      0.00      0.00        52
#            9       0.22      0.22      0.22       232
#
#     accuracy                           0.20      1443
#    macro avg       0.15      0.15      0.12      1443
# weighted avg       0.21      0.20      0.16      1443
#
# Predicted   0  1   3    6   7   9
# True
# 0          39  2  11   97  26  35
# 1          44  7  20   88  29  37
# 2           6  0   4   26   5   3
# 3          15  1  32   52  11  17
# 4           6  0   9   40   7  14
# 5          18  0   8   31   9  16
# 6          33  2  15  115  22  17
# 7          32  0  12   65  49  32
# 8           7  1   6   26   6   6
# 9          28  2  12  103  37  50
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
