# %%
from google.colab import drive
drive.mount('/gdrive')

# %%
# !pip install konlpy
# !pip install kss

# %%
# !git clone https://github.com/SOMJANG/Mecab-ko-for-Google-Colab.git

# %%
cd Mecab-ko-for-Google-Colab

# %%
# !bash install_mecab-ko_on_colab190912.sh

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import copy
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN, Activation
from tensorflow.keras import optimizers
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder; LE = LabelEncoder()
from sklearn.metrics import classification_report
from gensim.models.word2vec import Word2Vec
from konlpy.tag import Mecab

def rnn():
    model = Sequential()
    model.add(SimpleRNN(2 ** 3, input_shape=(max_len*100, 1), return_sequences=True))
    model.add(SimpleRNN(2 ** 3, return_sequences=True))
    model.add(SimpleRNN(2 ** 3, return_sequences=False))

    model.add(Dense(10))
    model.add(Activation('softmax'))
    adam = optimizers.Adam(lr=0.001)
    model.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy'])
    model.summary()
    early_stopping = EarlyStopping(patience=10)
    history = model.fit(x_train, y_train, validation_split=0.1, epochs=epochs, batch_size=batch_size, verbose=1, callbacks=[early_stopping])

    return model, history

if __name__ == "__main__":
    max_len = 32
    epochs = 2 ** 10
    batch_size = 2 ** 10

    mecab = Mecab()

    model = Word2Vec.load('/gdrive/My Drive/한양대학교/2020 프로젝트 학기제/TEST/word2vec')

    depression_dataset_path = r'/gdrive/My Drive/한양대학교/2020 프로젝트 학기제/TEST/depression_dataset_맞춤법O.csv'

    depression_dataset = pd.read_csv(depression_dataset_path, encoding='cp949')
    depression_dataset = depression_dataset[depression_dataset['label_1']=='Y']
    
    df = []

    for i in range(len(depression_dataset)):
        df.append(mecab.morphs(depression_dataset.iloc[i,0]))

    for i in range(len(df)):
        for j in range(len(df[i])):
            try:
                df[i][j] = model.wv.get_vector(df[i][j]).tolist()
            except:
                df[i][j] = False

    for i in range(len(df)):
        while False in df[i]:
            df[i].remove(False)

    for i in range(len(df)):
        if len(df[i]) >= max_len:
            df[i] = df[i][-32:]
        else:
            for j in range(max_len-len(df[i])):
                df[i].insert(0,0)

    for i in range(len(df)):
        for j in range(len(df[i])):
            if df[i][j] == 0:
                df[i][j] = [0]*100

    depression_dataset['label_2'] = LE.fit_transform(depression_dataset['label_2'])

    x_train, x_test, y_train, y_test = train_test_split(df, depression_dataset['label_2'], test_size=0.1, random_state=42)

    x_train = np.array(x_train).reshape((len(x_train), max_len*100, 1))
    x_test = np.array(x_test).reshape((len(x_test), max_len*100, 1))

    y_true = copy.deepcopy(y_test)
    y_train = to_categorical(y_train)
    y_test = to_categorical(y_test)

    print('train_shape : {} / {}'.format(x_train.shape, y_train.shape))
    print('test_shape : {} / {}'.format(x_test.shape, y_test.shape))

    model, history = rnn()

    scores = model.evaluate(x_test, y_test)
    print(scores)
    print("정확도: %.2f%%" % (scores[1] * 100))

    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs = range(1, len(acc) + 1)

    plt.plot(epochs, loss, 'r', label='Training loss')
    plt.plot(epochs, val_loss, 'b', label='Validation loss')
    plt.title('Training and validation loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.figure()
    plt.plot(epochs, acc, 'r', label='Training acc')
    plt.plot(epochs, val_acc, 'b', label='Validation acc')
    plt.title('Training and validation accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.show()

    y_true = list(y_true)
    y_pred = model.predict_classes(x_test)
    y_pred = list(y_pred)

    print(classification_report(y_true, y_pred))
    print(pd.crosstab(pd.Series(y_true), pd.Series(y_pred), rownames=['True'], colnames=['Predicted']))
# Out:
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:254: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# train_shape : (12984, 3200, 1) / (12984, 10)
# test_shape : (1443, 3200, 1) / (1443, 10)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn (SimpleRNN)       (None, 3200, 8)           80
# _________________________________________________________________
# simple_rnn_1 (SimpleRNN)     (None, 3200, 8)           136
# _________________________________________________________________
# simple_rnn_2 (SimpleRNN)     (None, 8)                 136
# _________________________________________________________________
# dense (Dense)                (None, 10)                90
# _________________________________________________________________
# activation (Activation)      (None, 10)                0
# =================================================================
# Total params: 442
# Trainable params: 442
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1024
# 12/12 [==============================] - 55s 5s/step - loss: 0.3242 - accuracy: 0.1327 - val_loss: 0.3210 - val_accuracy: 0.1355
# Epoch 2/1024
# 12/12 [==============================] - 55s 5s/step - loss: 0.3200 - accuracy: 0.1515 - val_loss: 0.3181 - val_accuracy: 0.1563
# Epoch 3/1024
# 12/12 [==============================] - 55s 5s/step - loss: 0.3174 - accuracy: 0.1558 - val_loss: 0.3162 - val_accuracy: 0.1486
# Epoch 4/1024
# 12/12 [==============================] - 56s 5s/step - loss: 0.3158 - accuracy: 0.1460 - val_loss: 0.3149 - val_accuracy: 0.1424
# Epoch 5/1024
# 12/12 [==============================] - 55s 5s/step - loss: 0.3147 - accuracy: 0.1437 - val_loss: 0.3141 - val_accuracy: 0.1378
# Epoch 6/1024
# 12/12 [==============================] - 56s 5s/step - loss: 0.3140 - accuracy: 0.1452 - val_loss: 0.3137 - val_accuracy: 0.1509
# Epoch 7/1024
# 12/12 [==============================] - 55s 5s/step - loss: 0.3134 - accuracy: 0.1418 - val_loss: 0.3134 - val_accuracy: 0.1393
# Epoch 8/1024
# 12/12 [==============================] - 55s 5s/step - loss: 0.3131 - accuracy: 0.1485 - val_loss: 0.3131 - val_accuracy: 0.1555
# Epoch 9/1024
# 12/12 [==============================] - 55s 5s/step - loss: 0.3128 - accuracy: 0.1495 - val_loss: 0.3130 - val_accuracy: 0.1440
# Epoch 10/1024
# 12/12 [==============================] - 55s 5s/step - loss: 0.3126 - accuracy: 0.1591 - val_loss: 0.3129 - val_accuracy: 0.1493
# Epoch 11/1024
# 12/12 [==============================] - 56s 5s/step - loss: 0.3124 - accuracy: 0.1534 - val_loss: 0.3128 - val_accuracy: 0.1493
# Epoch 12/1024
# 12/12 [==============================] - 54s 5s/step - loss: 0.3122 - accuracy: 0.1628 - val_loss: 0.3127 - val_accuracy: 0.1486
# Epoch 13/1024
# 12/12 [==============================] - 55s 5s/step - loss: 0.3121 - accuracy: 0.1630 - val_loss: 0.3126 - val_accuracy: 0.1540
# Epoch 14/1024
# 12/12 [==============================] - 55s 5s/step - loss: 0.3120 - accuracy: 0.1617 - val_loss: 0.3125 - val_accuracy: 0.1486
# Epoch 15/1024
# 12/12 [==============================] - 57s 5s/step - loss: 0.3119 - accuracy: 0.1619 - val_loss: 0.3125 - val_accuracy: 0.1524
# Epoch 16/1024
# 12/12 [==============================] - 56s 5s/step - loss: 0.3118 - accuracy: 0.1639 - val_loss: 0.3124 - val_accuracy: 0.1540
# Epoch 17/1024
# 12/12 [==============================] - 56s 5s/step - loss: 0.3117 - accuracy: 0.1648 - val_loss: 0.3123 - val_accuracy: 0.1509
# Epoch 18/1024
# 12/12 [==============================] - 55s 5s/step - loss: 0.3117 - accuracy: 0.1633 - val_loss: 0.3123 - val_accuracy: 0.1501
# Epoch 19/1024
# 12/12 [==============================] - 56s 5s/step - loss: 0.3116 - accuracy: 0.1633 - val_loss: 0.3123 - val_accuracy: 0.1493
# Epoch 20/1024
# 12/12 [==============================] - 55s 5s/step - loss: 0.3115 - accuracy: 0.1624 - val_loss: 0.3122 - val_accuracy: 0.1478
# Epoch 21/1024
# 12/12 [==============================] - 53s 4s/step - loss: 0.3115 - accuracy: 0.1642 - val_loss: 0.3121 - val_accuracy: 0.1524
# Epoch 22/1024
# 12/12 [==============================] - 53s 4s/step - loss: 0.3114 - accuracy: 0.1653 - val_loss: 0.3121 - val_accuracy: 0.1517
# Epoch 23/1024
# 12/12 [==============================] - 53s 4s/step - loss: 0.3114 - accuracy: 0.1667 - val_loss: 0.3120 - val_accuracy: 0.1532
# Epoch 24/1024
# 12/12 [==============================] - 53s 4s/step - loss: 0.3113 - accuracy: 0.1658 - val_loss: 0.3120 - val_accuracy: 0.1555
# Epoch 25/1024
# 12/12 [==============================] - 53s 4s/step - loss: 0.3113 - accuracy: 0.1647 - val_loss: 0.3119 - val_accuracy: 0.1570
# Epoch 26/1024
# 12/12 [==============================] - 54s 5s/step - loss: 0.3113 - accuracy: 0.1636 - val_loss: 0.3119 - val_accuracy: 0.1524
# Epoch 27/1024
# 12/12 [==============================] - 53s 4s/step - loss: 0.3112 - accuracy: 0.1689 - val_loss: 0.3118 - val_accuracy: 0.1547
# Epoch 28/1024
# 12/12 [==============================] - 53s 4s/step - loss: 0.3111 - accuracy: 0.1675 - val_loss: 0.3118 - val_accuracy: 0.1540
# Epoch 29/1024
# 12/12 [==============================] - 53s 4s/step - loss: 0.3111 - accuracy: 0.1662 - val_loss: 0.3117 - val_accuracy: 0.1640
# Epoch 30/1024
# 12/12 [==============================] - 53s 4s/step - loss: 0.3110 - accuracy: 0.1659 - val_loss: 0.3117 - val_accuracy: 0.1547
# Epoch 31/1024
# 12/12 [==============================] - 54s 5s/step - loss: 0.3110 - accuracy: 0.1677 - val_loss: 0.3116 - val_accuracy: 0.1624
# Epoch 32/1024
# 12/12 [==============================] - 55s 5s/step - loss: 0.3110 - accuracy: 0.1700 - val_loss: 0.3117 - val_accuracy: 0.1570
# Epoch 33/1024
# 12/12 [==============================] - 55s 5s/step - loss: 0.3109 - accuracy: 0.1709 - val_loss: 0.3116 - val_accuracy: 0.1586
# Epoch 34/1024
# 12/12 [==============================] - 55s 5s/step - loss: 0.3109 - accuracy: 0.1696 - val_loss: 0.3116 - val_accuracy: 0.1594
# Epoch 35/1024
# 12/12 [==============================] - 55s 5s/step - loss: 0.3108 - accuracy: 0.1697 - val_loss: 0.3116 - val_accuracy: 0.1563
# Epoch 36/1024
# 12/12 [==============================] - 56s 5s/step - loss: 0.3108 - accuracy: 0.1681 - val_loss: 0.3114 - val_accuracy: 0.1701
# Epoch 37/1024
# 12/12 [==============================] - 56s 5s/step - loss: 0.3108 - accuracy: 0.1723 - val_loss: 0.3115 - val_accuracy: 0.1617
# Epoch 38/1024
# 12/12 [==============================] - 55s 5s/step - loss: 0.3107 - accuracy: 0.1675 - val_loss: 0.3114 - val_accuracy: 0.1640
# Epoch 39/1024
# 12/12 [==============================] - 56s 5s/step - loss: 0.3107 - accuracy: 0.1700 - val_loss: 0.3114 - val_accuracy: 0.1594
# Epoch 40/1024
# 12/12 [==============================] - 56s 5s/step - loss: 0.3107 - accuracy: 0.1710 - val_loss: 0.3113 - val_accuracy: 0.1609
# Epoch 41/1024
# 12/12 [==============================] - 56s 5s/step - loss: 0.3106 - accuracy: 0.1729 - val_loss: 0.3114 - val_accuracy: 0.1617
# Epoch 42/1024
# 12/12 [==============================] - 58s 5s/step - loss: 0.3106 - accuracy: 0.1720 - val_loss: 0.3112 - val_accuracy: 0.1678
# Epoch 43/1024
# 12/12 [==============================] - 55s 5s/step - loss: 0.3105 - accuracy: 0.1732 - val_loss: 0.3112 - val_accuracy: 0.1686
# Epoch 44/1024
# 12/12 [==============================] - 55s 5s/step - loss: 0.3105 - accuracy: 0.1708 - val_loss: 0.3112 - val_accuracy: 0.1671
# Epoch 45/1024
# 12/12 [==============================] - 56s 5s/step - loss: 0.3105 - accuracy: 0.1697 - val_loss: 0.3111 - val_accuracy: 0.1640
# Epoch 46/1024
# 12/12 [==============================] - 56s 5s/step - loss: 0.3104 - accuracy: 0.1730 - val_loss: 0.3111 - val_accuracy: 0.1663
# Epoch 47/1024
# 12/12 [==============================] - 57s 5s/step - loss: 0.3104 - accuracy: 0.1736 - val_loss: 0.3109 - val_accuracy: 0.1617
# Epoch 48/1024
# 12/12 [==============================] - 56s 5s/step - loss: 0.3103 - accuracy: 0.1731 - val_loss: 0.3111 - val_accuracy: 0.1678
# Epoch 49/1024
# 12/12 [==============================] - 56s 5s/step - loss: 0.3103 - accuracy: 0.1749 - val_loss: 0.3110 - val_accuracy: 0.1647
# Epoch 50/1024
# 12/12 [==============================] - 55s 5s/step - loss: 0.3102 - accuracy: 0.1725 - val_loss: 0.3110 - val_accuracy: 0.1671
# Epoch 51/1024
# 12/12 [==============================] - 56s 5s/step - loss: 0.3102 - accuracy: 0.1743 - val_loss: 0.3109 - val_accuracy: 0.1678
# Epoch 52/1024
# 12/12 [==============================] - 57s 5s/step - loss: 0.3101 - accuracy: 0.1737 - val_loss: 0.3109 - val_accuracy: 0.1686
# Epoch 53/1024
# 12/12 [==============================] - 56s 5s/step - loss: 0.3101 - accuracy: 0.1738 - val_loss: 0.3109 - val_accuracy: 0.1686
# Epoch 54/1024
# 12/12 [==============================] - 56s 5s/step - loss: 0.3101 - accuracy: 0.1768 - val_loss: 0.3107 - val_accuracy: 0.1709
# Epoch 55/1024
# 12/12 [==============================] - 55s 5s/step - loss: 0.3100 - accuracy: 0.1755 - val_loss: 0.3108 - val_accuracy: 0.1724
# Epoch 56/1024
# 12/12 [==============================] - 56s 5s/step - loss: 0.3100 - accuracy: 0.1749 - val_loss: 0.3107 - val_accuracy: 0.1724
# Epoch 57/1024
# 12/12 [==============================] - 58s 5s/step - loss: 0.3099 - accuracy: 0.1754 - val_loss: 0.3106 - val_accuracy: 0.1717
# Epoch 58/1024
# 12/12 [==============================] - 56s 5s/step - loss: 0.3099 - accuracy: 0.1759 - val_loss: 0.3106 - val_accuracy: 0.1740
# Epoch 59/1024
# 12/12 [==============================] - 56s 5s/step - loss: 0.3098 - accuracy: 0.1753 - val_loss: 0.3107 - val_accuracy: 0.1686
# Epoch 60/1024
# 12/12 [==============================] - 56s 5s/step - loss: 0.3098 - accuracy: 0.1764 - val_loss: 0.3106 - val_accuracy: 0.1747
# Epoch 61/1024
# 12/12 [==============================] - 57s 5s/step - loss: 0.3097 - accuracy: 0.1761 - val_loss: 0.3107 - val_accuracy: 0.1717
# Epoch 62/1024
# 12/12 [==============================] - 58s 5s/step - loss: 0.3097 - accuracy: 0.1776 - val_loss: 0.3104 - val_accuracy: 0.1724
# Epoch 63/1024
# 12/12 [==============================] - 58s 5s/step - loss: 0.3096 - accuracy: 0.1746 - val_loss: 0.3105 - val_accuracy: 0.1763
# Epoch 64/1024
# 12/12 [==============================] - 57s 5s/step - loss: 0.3097 - accuracy: 0.1761 - val_loss: 0.3106 - val_accuracy: 0.1709
# Epoch 65/1024
# 12/12 [==============================] - 57s 5s/step - loss: 0.3097 - accuracy: 0.1783 - val_loss: 0.3106 - val_accuracy: 0.1763
# Epoch 66/1024
# 12/12 [==============================] - 58s 5s/step - loss: 0.3096 - accuracy: 0.1760 - val_loss: 0.3104 - val_accuracy: 0.1717
# Epoch 67/1024
# 12/12 [==============================] - 57s 5s/step - loss: 0.3095 - accuracy: 0.1763 - val_loss: 0.3105 - val_accuracy: 0.1724
# Epoch 68/1024
# 12/12 [==============================] - 58s 5s/step - loss: 0.3095 - accuracy: 0.1799 - val_loss: 0.3104 - val_accuracy: 0.1694
# Epoch 69/1024
# 12/12 [==============================] - 56s 5s/step - loss: 0.3094 - accuracy: 0.1768 - val_loss: 0.3103 - val_accuracy: 0.1701
# Epoch 70/1024
# 12/12 [==============================] - 57s 5s/step - loss: 0.3094 - accuracy: 0.1775 - val_loss: 0.3104 - val_accuracy: 0.1686
# Epoch 71/1024
# 12/12 [==============================] - 57s 5s/step - loss: 0.3093 - accuracy: 0.1787 - val_loss: 0.3102 - val_accuracy: 0.1717
# Epoch 72/1024
# 12/12 [==============================] - 57s 5s/step - loss: 0.3093 - accuracy: 0.1757 - val_loss: 0.3103 - val_accuracy: 0.1694
# Epoch 73/1024
# 12/12 [==============================] - 56s 5s/step - loss: 0.3093 - accuracy: 0.1803 - val_loss: 0.3103 - val_accuracy: 0.1709
# Epoch 74/1024
# 12/12 [==============================] - 58s 5s/step - loss: 0.3093 - accuracy: 0.1792 - val_loss: 0.3103 - val_accuracy: 0.1709
# Epoch 75/1024
# 12/12 [==============================] - 57s 5s/step - loss: 0.3092 - accuracy: 0.1793 - val_loss: 0.3102 - val_accuracy: 0.1763
# Epoch 76/1024
# 12/12 [==============================] - 58s 5s/step - loss: 0.3091 - accuracy: 0.1793 - val_loss: 0.3103 - val_accuracy: 0.1671
# Epoch 77/1024
# 12/12 [==============================] - 58s 5s/step - loss: 0.3094 - accuracy: 0.1766 - val_loss: 0.3101 - val_accuracy: 0.1763
# Epoch 78/1024
# 12/12 [==============================] - 59s 5s/step - loss: 0.3093 - accuracy: 0.1786 - val_loss: 0.3102 - val_accuracy: 0.1709
# Epoch 79/1024
# 12/12 [==============================] - 58s 5s/step - loss: 0.3091 - accuracy: 0.1807 - val_loss: 0.3101 - val_accuracy: 0.1794
# Epoch 80/1024
# 12/12 [==============================] - 58s 5s/step - loss: 0.3091 - accuracy: 0.1799 - val_loss: 0.3101 - val_accuracy: 0.1786
# Epoch 81/1024
# 12/12 [==============================] - 58s 5s/step - loss: 0.3090 - accuracy: 0.1816 - val_loss: 0.3102 - val_accuracy: 0.1717
# Epoch 82/1024
# 12/12 [==============================] - 58s 5s/step - loss: 0.3090 - accuracy: 0.1800 - val_loss: 0.3102 - val_accuracy: 0.1794
# Epoch 83/1024
# 12/12 [==============================] - 59s 5s/step - loss: 0.3089 - accuracy: 0.1807 - val_loss: 0.3101 - val_accuracy: 0.1671
# Epoch 84/1024
# 12/12 [==============================] - 57s 5s/step - loss: 0.3089 - accuracy: 0.1821 - val_loss: 0.3101 - val_accuracy: 0.1809
# Epoch 85/1024
# 12/12 [==============================] - 57s 5s/step - loss: 0.3089 - accuracy: 0.1838 - val_loss: 0.3100 - val_accuracy: 0.1794
# Epoch 86/1024
# 12/12 [==============================] - 57s 5s/step - loss: 0.3089 - accuracy: 0.1818 - val_loss: 0.3104 - val_accuracy: 0.1740
# Epoch 87/1024
# 12/12 [==============================] - 57s 5s/step - loss: 0.3090 - accuracy: 0.1788 - val_loss: 0.3101 - val_accuracy: 0.1724
# Epoch 88/1024
# 12/12 [==============================] - 56s 5s/step - loss: 0.3089 - accuracy: 0.1824 - val_loss: 0.3103 - val_accuracy: 0.1771
# Epoch 89/1024
# 12/12 [==============================] - 56s 5s/step - loss: 0.3092 - accuracy: 0.1748 - val_loss: 0.3106 - val_accuracy: 0.1709
# Epoch 90/1024
# 12/12 [==============================] - 56s 5s/step - loss: 0.3090 - accuracy: 0.1786 - val_loss: 0.3099 - val_accuracy: 0.1771
# Epoch 91/1024
# 12/12 [==============================] - 57s 5s/step - loss: 0.3088 - accuracy: 0.1820 - val_loss: 0.3100 - val_accuracy: 0.1763
# Epoch 92/1024
# 12/12 [==============================] - 57s 5s/step - loss: 0.3087 - accuracy: 0.1841 - val_loss: 0.3100 - val_accuracy: 0.1755
# Epoch 93/1024
# 12/12 [==============================] - 58s 5s/step - loss: 0.3087 - accuracy: 0.1826 - val_loss: 0.3099 - val_accuracy: 0.1763
# Epoch 94/1024
# 12/12 [==============================] - 56s 5s/step - loss: 0.3087 - accuracy: 0.1833 - val_loss: 0.3102 - val_accuracy: 0.1763
# Epoch 95/1024
# 12/12 [==============================] - 57s 5s/step - loss: 0.3087 - accuracy: 0.1837 - val_loss: 0.3098 - val_accuracy: 0.1809
# Epoch 96/1024
# 12/12 [==============================] - 57s 5s/step - loss: 0.3086 - accuracy: 0.1857 - val_loss: 0.3099 - val_accuracy: 0.1771
# Epoch 97/1024
# 12/12 [==============================] - 58s 5s/step - loss: 0.3085 - accuracy: 0.1866 - val_loss: 0.3100 - val_accuracy: 0.1848
# Epoch 98/1024
# 12/12 [==============================] - 59s 5s/step - loss: 0.3085 - accuracy: 0.1841 - val_loss: 0.3099 - val_accuracy: 0.1778
# Epoch 99/1024
# 12/12 [==============================] - 57s 5s/step - loss: 0.3086 - accuracy: 0.1878 - val_loss: 0.3100 - val_accuracy: 0.1771
# Epoch 100/1024
# 12/12 [==============================] - 57s 5s/step - loss: 0.3085 - accuracy: 0.1855 - val_loss: 0.3100 - val_accuracy: 0.1863
# Epoch 101/1024
# 12/12 [==============================] - 57s 5s/step - loss: 0.3084 - accuracy: 0.1893 - val_loss: 0.3099 - val_accuracy: 0.1909
# Epoch 102/1024
# 12/12 [==============================] - 57s 5s/step - loss: 0.3084 - accuracy: 0.1907 - val_loss: 0.3097 - val_accuracy: 0.1778
# Epoch 103/1024
# 12/12 [==============================] - 60s 5s/step - loss: 0.3085 - accuracy: 0.1885 - val_loss: 0.3107 - val_accuracy: 0.1855
# Epoch 104/1024
# 12/12 [==============================] - 58s 5s/step - loss: 0.3092 - accuracy: 0.1764 - val_loss: 0.3101 - val_accuracy: 0.1671
# Epoch 105/1024
# 12/12 [==============================] - 58s 5s/step - loss: 0.3085 - accuracy: 0.1830 - val_loss: 0.3098 - val_accuracy: 0.1817
# Epoch 106/1024
# 12/12 [==============================] - 58s 5s/step - loss: 0.3083 - accuracy: 0.1896 - val_loss: 0.3099 - val_accuracy: 0.1755
# Epoch 107/1024
# 12/12 [==============================] - 57s 5s/step - loss: 0.3083 - accuracy: 0.1889 - val_loss: 0.3099 - val_accuracy: 0.1740
# Epoch 108/1024
# 12/12 [==============================] - 58s 5s/step - loss: 0.3084 - accuracy: 0.1896 - val_loss: 0.3098 - val_accuracy: 0.1794
# Epoch 109/1024
# 12/12 [==============================] - 57s 5s/step - loss: 0.3082 - accuracy: 0.1896 - val_loss: 0.3098 - val_accuracy: 0.1801
# Epoch 110/1024
# 12/12 [==============================] - 56s 5s/step - loss: 0.3083 - accuracy: 0.1899 - val_loss: 0.3100 - val_accuracy: 0.1817
# Epoch 111/1024
# 12/12 [==============================] - 57s 5s/step - loss: 0.3090 - accuracy: 0.1888 - val_loss: 0.3103 - val_accuracy: 0.1794
# Epoch 112/1024
# 12/12 [==============================] - 57s 5s/step - loss: 0.3087 - accuracy: 0.1886 - val_loss: 0.3097 - val_accuracy: 0.1755
# 46/46 [==============================] - 11s 245ms/step - loss: 0.3077 - accuracy: 0.1830
# [0.30766525864601135, 0.1829521805047989]
# 정확도: 18.30%
# WARNING:tensorflow:From <ipython-input-6-3a0830863f2a>:117: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#               precision    recall  f1-score   support
#
#            0       0.17      0.20      0.18       210
#            1       0.19      0.28      0.22       225
#            2       0.00      0.00      0.00        44
#            3       0.44      0.09      0.14       128
#            4       0.00      0.00      0.00        76
#            5       0.00      0.00      0.00        82
#            6       0.15      0.37      0.22       204
#            7       0.19      0.18      0.19       190
#            8       0.00      0.00      0.00        52
#            9       0.23      0.16      0.19       232
#
#     accuracy                           0.18      1443
#    macro avg       0.14      0.13      0.11      1443
# weighted avg       0.18      0.18      0.16      1443
#
# Predicted   0   1   3   6   7   9
# True
# 0          41  50   4  68  25  22
# 1          47  63   4  51  33  27
# 2           5  10   0  22   4   3
# 3          20  27  11  44  12  14
# 4           9  18   1  32   8   8
# 5          18  24   0  23  11   6
# 6          35  45   3  76  31  14
# 7          24  42   1  61  35  27
# 8           9   6   0  26   7   4
# 9          29  54   1  89  21  38
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
