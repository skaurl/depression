# %%
from google.colab import drive
drive.mount('/gdrive')

# %%
# !pip install konlpy
# !pip install kss

# %%
# !git clone https://github.com/SOMJANG/Mecab-ko-for-Google-Colab.git

# %%
cd Mecab-ko-for-Google-Colab

# %%
# !bash install_mecab-ko_on_colab190912.sh

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import copy
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN, Activation, Bidirectional
from tensorflow.keras import optimizers
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder;

LE = LabelEncoder()
from sklearn.metrics import classification_report
from gensim.models.word2vec import Word2Vec
from konlpy.tag import Mecab


def birnn():
    model = Sequential()
    model.add(Bidirectional(SimpleRNN(2 ** 4, return_sequences=True), input_shape=(max_len*100, 1)))
    model.add(Bidirectional(SimpleRNN(2 ** 4, return_sequences=True)))
    model.add(Bidirectional(SimpleRNN(2 ** 4, return_sequences=False)))

    model.add(Dense(10))
    model.add(Activation('softmax'))
    adam = optimizers.Adam(lr=0.001)
    model.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy'])
    model.summary()
    early_stopping = EarlyStopping(patience=10)
    history = model.fit(x_train, y_train, validation_split=0.1, epochs=epochs, batch_size=batch_size, verbose=1,
                        callbacks=[early_stopping])

    return model, history


if __name__ == "__main__":
    max_len = 32
    epochs = 2 ** 10
    batch_size = 2 ** 10

    mecab = Mecab()

    model = Word2Vec.load('/gdrive/My Drive/한양대학교/2020 프로젝트 학기제/TEST/word2vec')

    depression_dataset_path = r'/gdrive/My Drive/한양대학교/2020 프로젝트 학기제/TEST/depression_dataset_맞춤법O.csv'

    depression_dataset = pd.read_csv(depression_dataset_path, encoding='cp949')
    depression_dataset = depression_dataset[depression_dataset['label_1'] == 'Y']

    df = []

    for i in range(len(depression_dataset)):
        df.append(mecab.morphs(depression_dataset.iloc[i, 0]))

    for i in range(len(df)):
        for j in range(len(df[i])):
            try:
                df[i][j] = model.wv.get_vector(df[i][j]).tolist()
            except:
                df[i][j] = False

    for i in range(len(df)):
        while False in df[i]:
            df[i].remove(False)

    for i in range(len(df)):
        if len(df[i]) >= max_len:
            df[i] = df[i][-max_len:]
        else:
            for j in range(max_len - len(df[i])):
                df[i].insert(0, 0)

    for i in range(len(df)):
        for j in range(len(df[i])):
            if df[i][j] == 0:
                df[i][j] = [0] * 100

    depression_dataset['label_2'] = LE.fit_transform(depression_dataset['label_2'])

    x_train, x_test, y_train, y_test = train_test_split(df, depression_dataset['label_2'], test_size=0.1,
                                                        random_state=42)

    x_train = np.array(x_train).reshape((len(x_train), max_len * 100, 1))
    x_test = np.array(x_test).reshape((len(x_test), max_len * 100, 1))

    y_true = copy.deepcopy(y_test)
    y_train = to_categorical(y_train)
    y_test = to_categorical(y_test)

    print('train_shape : {} / {}'.format(x_train.shape, y_train.shape))
    print('test_shape : {} / {}'.format(x_test.shape, y_test.shape))

    model, history = birnn()

    scores = model.evaluate(x_test, y_test)
    print(scores)
    print("정확도: %.2f%%" % (scores[1] * 100))

    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs = range(1, len(acc) + 1)

    plt.plot(epochs, loss, 'r', label='Training loss')
    plt.plot(epochs, val_loss, 'b', label='Validation loss')
    plt.title('Training and validation loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.figure()
    plt.plot(epochs, acc, 'r', label='Training acc')
    plt.plot(epochs, val_acc, 'b', label='Validation acc')
    plt.title('Training and validation accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.show()

    y_true = list(y_true)
    y_pred = model.predict_classes(x_test)
    y_pred = list(y_pred)

    print(classification_report(y_true, y_pred))
    print(pd.crosstab(pd.Series(y_true), pd.Series(y_pred), rownames=['True'], colnames=['Predicted']))
# Out:
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:254: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# train_shape : (12984, 3200, 1) / (12984, 10)
# test_shape : (1443, 3200, 1) / (1443, 10)
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_2 (Bidirection (None, 3200, 32)          576
# _________________________________________________________________
# bidirectional_3 (Bidirection (None, 3200, 32)          1568
# _________________________________________________________________
# bidirectional_4 (Bidirection (None, 32)                1568
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                330
# _________________________________________________________________
# activation_1 (Activation)    (None, 10)                0
# =================================================================
# Total params: 4,042
# Trainable params: 4,042
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1024
# 12/12 [==============================] - 167s 14s/step - loss: 0.3212 - accuracy: 0.1344 - val_loss: 0.3148 - val_accuracy: 0.1647
# Epoch 2/1024
# 12/12 [==============================] - 177s 15s/step - loss: 0.3142 - accuracy: 0.1421 - val_loss: 0.3127 - val_accuracy: 0.1440
# Epoch 3/1024
# 12/12 [==============================] - 177s 15s/step - loss: 0.3125 - accuracy: 0.1520 - val_loss: 0.3121 - val_accuracy: 0.1578
# Epoch 4/1024
# 12/12 [==============================] - 176s 15s/step - loss: 0.3117 - accuracy: 0.1623 - val_loss: 0.3117 - val_accuracy: 0.1663
# Epoch 5/1024
# 12/12 [==============================] - 176s 15s/step - loss: 0.3112 - accuracy: 0.1673 - val_loss: 0.3115 - val_accuracy: 0.1655
# Epoch 6/1024
# 12/12 [==============================] - 178s 15s/step - loss: 0.3108 - accuracy: 0.1694 - val_loss: 0.3113 - val_accuracy: 0.1686
# Epoch 7/1024
# 12/12 [==============================] - 176s 15s/step - loss: 0.3106 - accuracy: 0.1674 - val_loss: 0.3112 - val_accuracy: 0.1724
# Epoch 8/1024
# 12/12 [==============================] - 176s 15s/step - loss: 0.3104 - accuracy: 0.1760 - val_loss: 0.3108 - val_accuracy: 0.1647
# Epoch 9/1024
# 12/12 [==============================] - 177s 15s/step - loss: 0.3102 - accuracy: 0.1728 - val_loss: 0.3108 - val_accuracy: 0.1840
# Epoch 10/1024
# 12/12 [==============================] - 175s 15s/step - loss: 0.3100 - accuracy: 0.1785 - val_loss: 0.3104 - val_accuracy: 0.1732
# Epoch 11/1024
# 12/12 [==============================] - 177s 15s/step - loss: 0.3099 - accuracy: 0.1777 - val_loss: 0.3105 - val_accuracy: 0.1824
# Epoch 12/1024
# 12/12 [==============================] - 176s 15s/step - loss: 0.3097 - accuracy: 0.1788 - val_loss: 0.3101 - val_accuracy: 0.1724
# Epoch 13/1024
# 12/12 [==============================] - 176s 15s/step - loss: 0.3095 - accuracy: 0.1812 - val_loss: 0.3102 - val_accuracy: 0.1755
# Epoch 14/1024
# 12/12 [==============================] - 175s 15s/step - loss: 0.3093 - accuracy: 0.1825 - val_loss: 0.3100 - val_accuracy: 0.1778
# Epoch 15/1024
# 12/12 [==============================] - 177s 15s/step - loss: 0.3091 - accuracy: 0.1850 - val_loss: 0.3101 - val_accuracy: 0.1863
# Epoch 16/1024
# 12/12 [==============================] - 177s 15s/step - loss: 0.3093 - accuracy: 0.1861 - val_loss: 0.3102 - val_accuracy: 0.1786
# Epoch 17/1024
# 12/12 [==============================] - 176s 15s/step - loss: 0.3091 - accuracy: 0.1844 - val_loss: 0.3099 - val_accuracy: 0.1778
# Epoch 18/1024
# 12/12 [==============================] - 176s 15s/step - loss: 0.3089 - accuracy: 0.1890 - val_loss: 0.3100 - val_accuracy: 0.1932
# Epoch 19/1024
# 12/12 [==============================] - 177s 15s/step - loss: 0.3088 - accuracy: 0.1878 - val_loss: 0.3098 - val_accuracy: 0.1824
# Epoch 20/1024
# 12/12 [==============================] - 177s 15s/step - loss: 0.3087 - accuracy: 0.1865 - val_loss: 0.3099 - val_accuracy: 0.1886
# Epoch 21/1024
# 12/12 [==============================] - 177s 15s/step - loss: 0.3085 - accuracy: 0.1851 - val_loss: 0.3095 - val_accuracy: 0.1771
# Epoch 22/1024
# 12/12 [==============================] - 176s 15s/step - loss: 0.3085 - accuracy: 0.1890 - val_loss: 0.3097 - val_accuracy: 0.1878
# Epoch 23/1024
# 12/12 [==============================] - 177s 15s/step - loss: 0.3082 - accuracy: 0.1896 - val_loss: 0.3096 - val_accuracy: 0.1886
# Epoch 24/1024
# 12/12 [==============================] - 177s 15s/step - loss: 0.3081 - accuracy: 0.1892 - val_loss: 0.3095 - val_accuracy: 0.1978
# Epoch 25/1024
# 12/12 [==============================] - 177s 15s/step - loss: 0.3081 - accuracy: 0.1918 - val_loss: 0.3095 - val_accuracy: 0.1901
# Epoch 26/1024
# 12/12 [==============================] - 177s 15s/step - loss: 0.3079 - accuracy: 0.1886 - val_loss: 0.3099 - val_accuracy: 0.1817
# Epoch 27/1024
# 12/12 [==============================] - 178s 15s/step - loss: 0.3079 - accuracy: 0.1908 - val_loss: 0.3096 - val_accuracy: 0.1763
# Epoch 28/1024
# 12/12 [==============================] - 177s 15s/step - loss: 0.3077 - accuracy: 0.1948 - val_loss: 0.3092 - val_accuracy: 0.1909
# Epoch 29/1024
# 12/12 [==============================] - 175s 15s/step - loss: 0.3076 - accuracy: 0.1918 - val_loss: 0.3095 - val_accuracy: 0.1917
# Epoch 30/1024
# 12/12 [==============================] - 178s 15s/step - loss: 0.3075 - accuracy: 0.1941 - val_loss: 0.3092 - val_accuracy: 0.1801
# Epoch 31/1024
# 12/12 [==============================] - 177s 15s/step - loss: 0.3074 - accuracy: 0.1910 - val_loss: 0.3098 - val_accuracy: 0.1871
# Epoch 32/1024
# 12/12 [==============================] - 176s 15s/step - loss: 0.3074 - accuracy: 0.1920 - val_loss: 0.3091 - val_accuracy: 0.1855
# Epoch 33/1024
# 12/12 [==============================] - 177s 15s/step - loss: 0.3073 - accuracy: 0.1914 - val_loss: 0.3093 - val_accuracy: 0.1855
# Epoch 34/1024
# 12/12 [==============================] - 176s 15s/step - loss: 0.3071 - accuracy: 0.1934 - val_loss: 0.3094 - val_accuracy: 0.1871
# Epoch 35/1024
# 12/12 [==============================] - 177s 15s/step - loss: 0.3070 - accuracy: 0.1933 - val_loss: 0.3091 - val_accuracy: 0.1871
# Epoch 36/1024
# 12/12 [==============================] - 178s 15s/step - loss: 0.3069 - accuracy: 0.1992 - val_loss: 0.3094 - val_accuracy: 0.1809
# Epoch 37/1024
# 12/12 [==============================] - 177s 15s/step - loss: 0.3068 - accuracy: 0.1945 - val_loss: 0.3093 - val_accuracy: 0.1809
# Epoch 38/1024
# 12/12 [==============================] - 177s 15s/step - loss: 0.3068 - accuracy: 0.1948 - val_loss: 0.3094 - val_accuracy: 0.1778
# Epoch 39/1024
# 12/12 [==============================] - 176s 15s/step - loss: 0.3066 - accuracy: 0.1959 - val_loss: 0.3093 - val_accuracy: 0.1863
# Epoch 40/1024
# 12/12 [==============================] - 177s 15s/step - loss: 0.3065 - accuracy: 0.1990 - val_loss: 0.3093 - val_accuracy: 0.1978
# Epoch 41/1024
# 12/12 [==============================] - 178s 15s/step - loss: 0.3065 - accuracy: 0.1978 - val_loss: 0.3098 - val_accuracy: 0.1724
# Epoch 42/1024
# 12/12 [==============================] - 178s 15s/step - loss: 0.3068 - accuracy: 0.1998 - val_loss: 0.3100 - val_accuracy: 0.1801
# 46/46 [==============================] - 21s 467ms/step - loss: 0.3077 - accuracy: 0.1885
# [0.3077484965324402, 0.1884961873292923]
# 정확도: 18.85%
# WARNING:tensorflow:From <ipython-input-2-c63b843f9be4>:123: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#               precision    recall  f1-score   support
#
#            0       0.15      0.08      0.10       210
#            1       0.18      0.11      0.14       225
#            2       0.00      0.00      0.00        44
#            3       0.23      0.23      0.23       128
#            4       0.00      0.00      0.00        76
#            5       0.00      0.00      0.00        82
#            6       0.17      0.53      0.26       204
#            7       0.21      0.33      0.26       190
#            8       0.00      0.00      0.00        52
#            9       0.23      0.12      0.16       232
#
#     accuracy                           0.19      1443
#    macro avg       0.12      0.14      0.12      1443
# weighted avg       0.16      0.19      0.15      1443
#
# Predicted   0   1   3    6   7  8   9
# True
# 0          17  24  14   98  35  1  21
# 1          19  25  21   92  48  0  20
# 2           4   6   2   27   3  0   2
# 3           8   9  30   46  26  0   9
# 4           9   1   4   44  11  0   7
# 5           6  14   7   34  11  0  10
# 6          15  18  21  109  34  0   7
# 7          14  22  12   62  63  0  17
# 8           7   1   3   28  10  0   3
# 9          16  22  14   97  55  0  28
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
